# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 4s 1us/step

# %% [markdown]
# ### Gettin to know the data

# %%
class_names = ['t-shirt','trouser','pullover','dress', 'coat', 'sandal', 'shirt','sneaker','bag','boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_images)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_images)
# Out:
# 10000

# %%
test_labels
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# normalize pixels values currently [0-255] in a [0-1] scale
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (10,10))
for i in range (25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i],cmap = plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]]).set_color('white')
plt.show()

# %%
# building the model
model = keras.Sequential([
    # re-formatting data to a Flat array of 28 x 28
    keras.layers.Flatten(input_shape=(28,28)),
    # 128 nodes (neurons)
    keras.layers.Dense(128, activation=tf.nn.relu),
    # 10 nodes (neurons) final output of 10 possible classes each node represented by a probability
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(
    # how the model is adjusted
    optimizer='adam',
    # loss function (measures accuracy)
    loss='sparse_categorical_crossentropy',
    # monitor steps' adjustment based on: 
    metrics=['accuracy']   
)

# %%
# train the model
model.fit(train_images, train_labels, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.4964 - accuracy: 0.8264
# Epoch 2/5
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.3747 - accuracy: 0.8648
# Epoch 3/5
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.3355 - accuracy: 0.8780
# Epoch 4/5
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.3112 - accuracy: 0.8862
# Epoch 5/5
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.2952 - accuracy: 0.8899

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test Loss: ',test_loss,' Test Accuracy: ',test_acc)
# Out:
# 10000/10000 [==============================] - 1s 74us/sample - loss: 0.3360 - accuracy: 0.8791
# Test Loss:  0.3359626438617706  Test Accuracy:  0.8791

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([2.9671576e-06, 7.2187722e-09, 5.0928014e-07, 3.7955697e-08,
#        3.2871750e-07, 4.7721984e-03, 1.1061155e-05, 6.1357480e-02,
#        8.7648385e-07, 9.3385452e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# this indicates that the class wich greatest confidente (prediction) is class # 9 (boot)
# Out:
# 9

# %%
test_labels[0]
# indicates the final decision by the model in label format
# Out:
# 9

# %%
def plot_image(i,predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.binary)
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'green'
    else:
        color = 'red'
    
    plt.xlabel("{} {:2.0f}% ({})".format(
            class_names[predicted_label],
            100*np.max(predictions_array),
        class_names[true_label]), color=color)

# %%
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#FF0000")
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('green')

# %%
rows = 5
cols = 3
num_images = rows * cols
plt.figure(figsize = (3*2*cols, 3*rows) )
for i in range(num_images):
    plt.subplot(rows,2*cols,2*i+1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(rows,2*cols,2*i+2)
    plot_value_array(i, predictions, test_labels)
plt.show()

# %%
# single plot
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
plt.show()

# %%
# single prediction
img = test_images[0]
print(img.shape)
# Out:
# (28, 28)

# %%
img = (np.expand_dims(img,0))
print (img.shape)
# Out:
# (1, 28, 28)

# %%
single_p = model.predict(img)
print(single_p)
# Out:
# [[2.96715734e-06 7.21877180e-09 5.09280085e-07 3.79557683e-08
#   3.28717817e-07 4.77219140e-03 1.10611545e-05 6.13575242e-02
#   8.76483796e-07 9.33854461e-01]]

# %%
plot_value_array(0, single_p, test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)
print("\n Prediction: ",np.argmax(single_p[0]), "\n")
# Out:
#  Prediction:  9
